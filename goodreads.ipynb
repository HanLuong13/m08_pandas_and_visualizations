# %%
import pandas as pd

# %%
books = pd.read_csv('books.csv')
print(books)
# Out:
#       book_id  goodreads_book_id  best_book_id   work_id  books_count  \
# 0           1            2767052       2767052   2792775          272
# 1           2                  3             3   4640799          491
# 2           3              41865         41865   3212258          226
# 3           4               2657          2657   3275794          487
# 4           5               4671          4671    245494         1356
# ...       ...                ...           ...       ...          ...
# 9995     9996            7130616       7130616   7392860           19
# 9996     9997             208324        208324   1084709           19
# 9997     9998              77431         77431   2393986           60
# 9998     9999            8565083       8565083  13433613            7
# 9999    10000               8914          8914     11817           31
#
#             isbn        isbn13                      authors  \
# 0      439023483  9.780439e+12              Suzanne Collins
# ...

# %%
books.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 23 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   book_id                    10000 non-null  int64
#  1   goodreads_book_id          10000 non-null  int64
#  2   best_book_id               10000 non-null  int64
#  3   work_id                    10000 non-null  int64
#  4   books_count                10000 non-null  int64
#  5   isbn                       9300 non-null   object
#  6   isbn13                     9415 non-null   float64
#  7   authors                    10000 non-null  object
#  8   original_publication_year  9979 non-null   float64
#  9   original_title             9415 non-null   object
#  10  title                      10000 non-null  object
#  11  language_code              8916 non-null   object
#  12  average_rating             10000 non-null  float64
# ...

# %%
books = books.dropna(subset = ['isbn', 'isbn13', 'language_code','original_publication_year'])
print(books.head())
# Out:
#    book_id  goodreads_book_id  best_book_id  work_id  books_count       isbn  \
# 0        1            2767052       2767052  2792775          272  439023483
# 1        2                  3             3  4640799          491  439554934
# 2        3              41865         41865  3212258          226  316015849
# 3        4               2657          2657  3275794          487   61120081
# 4        5               4671          4671   245494         1356  743273567
#
#          isbn13                      authors  original_publication_year  \
# 0  9.780439e+12              Suzanne Collins                     2008.0
# 1  9.780440e+12  J.K. Rowling, Mary GrandPré                     1997.0
# 2  9.780316e+12              Stephenie Meyer                     2005.0
# 3  9.780061e+12                   Harper Lee                     1960.0
# 4  9.780743e+12          F. Scott Fitzgerald                     1925.0
#
#                              original_title  ... ratings_count  \
# ...

# %%
books = pd.read_csv('books.csv')
books = books.dropna(subset = ['isbn', 'isbn13', 'language_code','original_publication_year'])

books['isbn13'] = books['isbn13'].astype('int64').astype('str')  

for number in books['isbn13']:
    isbn = '{}-{}-{}-{}-{}'.format(number[0:3],number[3:4],number[4:9],number[9:12],number[12:])
    print(isbn)
# Out:
# 978-0-43902-348-0
# 978-0-43955-493-0
# 978-0-31601-584-0
# 978-0-06112-008-0
# 978-0-74327-356-0
# 978-0-52547-881-0
# 978-0-61826-030-0
# 978-0-31676-917-0
# 978-1-41652-479-0
# 978-0-67978-327-0
# 978-1-59448-000-0
# 978-0-06202-404-0
# 978-0-45152-494-0
# 978-0-45228-424-0
# 978-0-55329-698-0
# 978-0-30726-975-0
# 978-0-43902-350-0
# 978-0-43965-548-0
# 978-0-61834-626-0
# 978-0-43902-351-0
# 978-0-43935-807-0
# 978-0-31616-668-0
# 978-0-43906-487-0
# 978-0-43913-960-0
# 978-0-54501-022-0
# 978-0-30727-767-0
# 978-0-43978-597-0
# 978-0-14028-333-0
# 978-0-74347-712-0
# 978-0-29785-938-0
# 978-0-39915-534-0
# 978-0-14200-067-0
# 978-0-73932-622-0
# 978-1-61213-029-0
# 978-0-06112-242-0
# 978-0-38573-255-0
# 978-0-06076-489-0
# 978-0-96581-867-0
# 978-0-55358-848-0
# 978-0-14303-841-0
# 978-0-78683-865-0
# 978-0-45152-930-0
# 978-0-14243-721-0
# 978-0-55381-672-0
# 978-1-56512-560-0
# 978-0-37583-100-0
# 978-0-30734-798-0
# 978-0-31616-019-0
# 978-0-06051-303-0
# 978-1-41691-428-0
# ...

# %%
books = pd.read_csv('books.csv')
books = books.dropna(subset = ['isbn', 'isbn13', 'language_code','original_publication_year'])
books['isbn13'] = books['isbn13'].astype('int64').astype('str') 

def func(string):
    string = '{}-{}-{}-{}-{}'.format(string[0:3],string[3:4],string[4:9],string[9:12],string[12:])
    return string

books['isbn13'] = books['isbn13'].apply(func)

books['isbn13']
# Out:
# 0       978-0-43902-348-0
# 1       978-0-43955-493-0
# 2       978-0-31601-584-0
# 3       978-0-06112-008-0
# 4       978-0-74327-356-0
#               ...
# 9994    978-1-41652-373-0
# 9995    978-0-44101-946-0
# 9996    978-0-67973-371-0
# 9997    978-0-39330-763-0
# 9998    978-0-06171-153-0
# Name: isbn13, Length: 8225, dtype: object

# %%
books.assign(difference_title = books['title'] == books['original_title'])
# Out:
#       book_id  goodreads_book_id  best_book_id   work_id  books_count  \
# 0           1            2767052       2767052   2792775          272
# 1           2                  3             3   4640799          491
# 2           3              41865         41865   3212258          226
# 3           4               2657          2657   3275794          487
# 4           5               4671          4671    245494         1356
# ...       ...                ...           ...       ...          ...
# 9994     9995              15613         15613   2764239          199
# 9995     9996            7130616       7130616   7392860           19
# 9996     9997             208324        208324   1084709           19
# 9997     9998              77431         77431   2393986           60
# 9998     9999            8565083       8565083  13433613            7
#
#             isbn             isbn13                      authors  \
# ...

# %%
books['authors'].str.split(',', expand=True)
# Out:
#                        0               1     2     3     4     5     6     7   \
# 0         Suzanne Collins            None  None  None  None  None  None  None
# 1            J.K. Rowling   Mary GrandPré  None  None  None  None  None  None
# 2         Stephenie Meyer            None  None  None  None  None  None  None
# 3              Harper Lee            None  None  None  None  None  None  None
# 4     F. Scott Fitzgerald            None  None  None  None  None  None  None
# ...                   ...             ...   ...   ...   ...   ...   ...   ...
# 9994      Herman Melville            None  None  None  None  None  None  None
# 9995        Ilona Andrews            None  None  None  None  None  None  None
# 9996       Robert A. Caro            None  None  None  None  None  None  None
# 9997      Patrick O'Brian            None  None  None  None  None  None  None
# 9998      Peggy Orenstein            None  None  None  None  None  None  None
#
# ...

# %%
books.original_publication_year.astype(int)

books_year = books.original_publication_year.unique()
with pd.ExcelWriter('books_by_year.xlsx') as xlsxWriter:
    for year in books_year:
        if 1800 <= year <= 1899: 
            books[books.original_publication_year == year].to_excel(xlsxWriter,sheet_name='1800-1899')
        elif 1900 <= year <= 1999:
            books[books.original_publication_year == year].to_excel(xlsxWriter,sheet_name='1900-1999')
        elif 2000 <= year <= 2099:
            books[books.original_publication_year == year].to_excel(xlsxWriter,sheet_name='2000-2099')

xlsxWriter.save()
# Out:
# H:\anaconda3\lib\site-packages\xlsxwriter\workbook.py:338: UserWarning: Calling close() on already closed file.
#   warn("Calling close() on already closed file.")
